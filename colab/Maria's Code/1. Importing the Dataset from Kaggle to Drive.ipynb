# %% [markdown]
# # Get in the right folder
#
# Root folder must store kaggle.json file

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
GIT_FOLDER_NAME = 'Kaggle-ML/Neuromatch_Project'
GIT_FOLDER_PATH = f'drive/My Drive/{GIT_FOLDER_NAME}/'
# %cd "{GIT_FOLDER_PATH}"

# %% [markdown]
# # Configuring Kaggle Connection
# Step 1: Get kaggle.json from Profile > Account > Create new API token
#
# Step 2: Save kaggle.json in root folder

# %%
# !pip install kaggle

# %%
# !mkdir ~/.kaggle

# %%
# !cp kaggle.json ~/.kaggle/

# %%
# !chmod 600 ~/.kaggle/kaggle.json

# %% [markdown]
# # Download the dataset
# It will unzip it to Root/dataset

# %%
# !kaggle datasets download -d sartajbhuvaji/brain-tumor-classification-mri

# %%
# !unzip brain-tumor-classification-mri.zip -d dataset/
